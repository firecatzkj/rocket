# %%
import os
import pandas as pd
from sklearn import tree

# %%
os.chdir("E:\\mycode\\rocket\\smbinning")
df = pd.read_csv("../data/hl_test_clean.csv")

# %%
y = df["fpd"]
x_test = df[["hl_phone_silent_frequentcy", ]]
mytree = tree.DecisionTreeClassifier(
    max_features=1,
    min_weight_fraction_leaf=0.05,
    criterion="entropy",
    max_leaf_nodes=5)
mytree.fit(x_test, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=1, max_leaf_nodes=5, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.05,
#             presort=False, random_state=None, splitter='best')

# %%
from IPython.display import Image 
import pydotplus 
dot_data = tree.export_graphviz(mytree, out_file=None, 
                         feature_names=["hl_phone_silent_frequentcy", ],  
         
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
mytree.tree_.threshold
# Out:
# array([ 0.00638984,  0.00566577,  0.08657658,  0.01671322, -2.        ,
#        -2.        , -2.        , -2.        , -2.        ])
